# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
studio_and_budgets = pd.read_csv('studio_and_budget.csv') #Uploaded the dataframe
studio_and_budgets
# Out:
#                                             title studio  domestic_gross  \
# 0                                     Toy Story 3     BV     415000000.0
# 1                      Alice in Wonderland (2010)     BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                       Inception     WB     292600000.0
# 4                             Shrek Forever After   P/DW     238700000.0
# ...                                           ...    ...             ...
# 7926                                       Red 11    NaN             NaN
# 7927                                    Following    NaN             NaN
# 7928                Return to the Land of Wonders    NaN             NaN
# 7929                         A Plague So Pleasant    NaN             NaN
# 7930                            My Date With Drew    NaN             NaN
#
#      foreign_gross    year    id production_budget
# 0        652000000  2010.0  47.0      $200,000,000
# 1        691300000  2010.0   NaN               NaN
# 2        664300000  2010.0   NaN               NaN
# 3        535700000  2010.0  38.0      $160,000,000
# 4        513900000  2010.0  27.0      $165,000,000
# ...            ...     ...   ...               ...
# 7926           NaN     NaN  78.0            $7,000
# 7927           NaN     NaN  79.0            $6,000
# 7928           NaN     NaN  80.0            $5,000
# 7929           NaN     NaN  81.0            $1,400
# 7930           NaN     NaN  82.0            $1,100
#
# [7931 rows x 7 columns]

# %%
gross_and_prod = studio_and_budgets.dropna(subset=['domestic_gross', 'foreign_gross', 'production_budget'])

#I decided to drop the NA values in the domestic gross, foriegn gross, and production budget in order to be able to use the 
#data given more effectively

# %%
gross_and_prod.sort_values(by=["production_budget"], ascending=False).head(10)
#production budget isnt sorting correctly
# Out:
#                              title   studio  domestic_gross foreign_gross  \
# 20                      Robin Hood     Uni.     105300000.0     216400000
# 1908             The Peanuts Movie      Fox     130199999.0     116100000
# 2807               Alien: Covenant      Fox      74300000.0     166600000
# 1268                        Trance     FoxS       2300000.0      21900000
# 26              Sex and the City 2  WB (NL)      95300000.0     193000000
# 795                   The Campaign       WB      86900000.0      18000000
# 1937                   Seventh Son     Uni.      17200000.0      97000000
# 45                     Unstoppable      Fox      81600000.0      86200000
# 735     Ice Age: Continental Drift      Fox     161300000.0     715900000
# 1896  Kingsman: The Secret Service      Fox     128300000.0     286100000
#
#         year    id production_budget
# 20    2010.0   9.0       $99,000,000
# 1908  2015.0   7.0       $99,000,000
# 2807  2017.0  12.0       $97,000,000
# 1268  2013.0  31.0          $950,000
# 26    2010.0  16.0       $95,000,000
# 795   2012.0  18.0       $95,000,000
# 1937  2015.0  24.0       $95,000,000
# 45    2010.0  19.0       $95,000,000
# 735   2012.0  14.0       $95,000,000
# 1896  2015.0  29.0       $94,000,000

# %%
gross_and_prod.info()# I noticed that production budget is still an object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1084 entries, 0 to 3280
# Data columns (total 7 columns):
# title                1084 non-null object
# studio               1083 non-null object
# domestic_gross       1084 non-null float64
# foreign_gross        1084 non-null object
# year                 1084 non-null float64
# id                   1084 non-null float64
# production_budget    1084 non-null object
# dtypes: float64(3), object(4)
# memory usage: 67.8+ KB

# %%
def clean_currency(x):# I'm going to use this function to clean out the string
  
    if isinstance(x, str):
        return(x.replace('$', '').replace(',', ''))
    return(x)

# %%
gross_and_prod['production_budget'] = gross_and_prod['production_budget'].apply(clean_currency).astype('float')
gross_and_prod
#Applied it to the production column and switched it to a float
# Out:
# C:\Users\eduar\anaconda3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                            title       studio  domestic_gross foreign_gross  \
# 0                    Toy Story 3           BV     415000000.0     652000000
# 3                      Inception           WB     292600000.0     535700000
# 4            Shrek Forever After         P/DW     238700000.0     513900000
# 5     The Twilight Saga: Eclipse         Sum.     300500000.0     398000000
# 6                     Iron Man 2         Par.     312400000.0     311500000
# ...                          ...          ...             ...           ...
# 3229               Hotel Artemis  Global Road       6700000.0       6000000
# 3238                         Kin          LGF       5700000.0       4300000
# 3245                    Suspiria       Amazon       2500000.0       5400000
# 3256                   Destroyer    Annapurna       1500000.0       4000000
# 3280  Bilal: A New Breed of Hero           VE        491000.0       1700000
#
#         year     id  production_budget
# 0     2010.0   47.0        200000000.0
# 3     2010.0   38.0        160000000.0
# 4     2010.0   27.0        165000000.0
# 5     2010.0   53.0         68000000.0
# 6     2010.0   15.0        170000000.0
# ...      ...    ...                ...
# 3229  2018.0   15.0         15000000.0
# 3238  2018.0   88.0         30000000.0
# 3245  2018.0   81.0         20000000.0
# 3256  2018.0    5.0          9000000.0
# 3280  2018.0  100.0         30000000.0
#
# [1084 rows x 7 columns]

# %%
gross_and_prod.info()# Much better. Now I have to change the foreign column to a float
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1084 entries, 0 to 3280
# Data columns (total 7 columns):
# title                1084 non-null object
# studio               1083 non-null object
# domestic_gross       1084 non-null float64
# foreign_gross        1084 non-null object
# year                 1084 non-null float64
# id                   1084 non-null float64
# production_budget    1084 non-null float64
# dtypes: float64(4), object(3)
# memory usage: 67.8+ KB

# %%
gross_and_prod['foreign_gross'] = gross_and_prod['foreign_gross'].apply(clean_currency).astype('float')
# Out:
# C:\Users\eduar\anaconda3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
gross_and_prod.info() #corrected the foreign column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1084 entries, 0 to 3280
# Data columns (total 7 columns):
# title                1084 non-null object
# studio               1083 non-null object
# domestic_gross       1084 non-null float64
# foreign_gross        1084 non-null float64
# year                 1084 non-null float64
# id                   1084 non-null float64
# production_budget    1084 non-null float64
# dtypes: float64(5), object(2)
# memory usage: 67.8+ KB

# %%
gross_and_prod.sort_values(by=["production_budget"], ascending=False)
print(gross_and_prod)
# Out:
#                            title       studio  domestic_gross  foreign_gross  \
# 0                    Toy Story 3           BV     415000000.0    652000000.0
# 3                      Inception           WB     292600000.0    535700000.0
# 4            Shrek Forever After         P/DW     238700000.0    513900000.0
# 5     The Twilight Saga: Eclipse         Sum.     300500000.0    398000000.0
# 6                     Iron Man 2         Par.     312400000.0    311500000.0
# ...                          ...          ...             ...            ...
# 3229               Hotel Artemis  Global Road       6700000.0      6000000.0
# 3238                         Kin          LGF       5700000.0      4300000.0
# 3245                    Suspiria       Amazon       2500000.0      5400000.0
# 3256                   Destroyer    Annapurna       1500000.0      4000000.0
# 3280  Bilal: A New Breed of Hero           VE        491000.0      1700000.0
#
#         year     id  production_budget
# 0     2010.0   47.0        200000000.0
# 3     2010.0   38.0        160000000.0
# 4     2010.0   27.0        165000000.0
# 5     2010.0   53.0         68000000.0
# 6     2010.0   15.0        170000000.0
# ...      ...    ...                ...
# 3229  2018.0   15.0         15000000.0
# 3238  2018.0   88.0         30000000.0
# 3245  2018.0   81.0         20000000.0
# 3256  2018.0    5.0          9000000.0
# 3280  2018.0  100.0         30000000.0
#
# [1084 rows x 7 columns]

# %%
gross_and_prod['profitability'] = (gross_and_prod['domestic_gross'] + gross_and_prod['foreign_gross']) - gross_and_prod['production_budget']
gross_and_prod.head()#I added domestic and foriegn then subtracted the sum by product budget to come up with the profitability column
# Out:
# C:\Users\eduar\anaconda3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                         title studio  domestic_gross  foreign_gross    year  \
# 0                 Toy Story 3     BV     415000000.0    652000000.0  2010.0
# 3                   Inception     WB     292600000.0    535700000.0  2010.0
# 4         Shrek Forever After   P/DW     238700000.0    513900000.0  2010.0
# 5  The Twilight Saga: Eclipse   Sum.     300500000.0    398000000.0  2010.0
# 6                  Iron Man 2   Par.     312400000.0    311500000.0  2010.0
#
#      id  production_budget  profitability
# 0  47.0        200000000.0    867000000.0
# 3  38.0        160000000.0    668300000.0
# 4  27.0        165000000.0    587600000.0
# 5  53.0         68000000.0    630500000.0
# 6  15.0        170000000.0    453900000.0

# %%
unique_titles = gross_and_prod['title'].nunique()
print(unique_titles)# there are 7 duplicate titles
# Out:
# 1077

# %%
gross_and_prod = gross_and_prod.drop_duplicates(subset='title', keep="first")
print(gross_and_prod) #no more duplicate titles
# Out:
#                            title       studio  domestic_gross  foreign_gross  \
# 0                    Toy Story 3           BV     415000000.0    652000000.0
# 3                      Inception           WB     292600000.0    535700000.0
# 4            Shrek Forever After         P/DW     238700000.0    513900000.0
# 5     The Twilight Saga: Eclipse         Sum.     300500000.0    398000000.0
# 6                     Iron Man 2         Par.     312400000.0    311500000.0
# ...                          ...          ...             ...            ...
# 3229               Hotel Artemis  Global Road       6700000.0      6000000.0
# 3238                         Kin          LGF       5700000.0      4300000.0
# 3245                    Suspiria       Amazon       2500000.0      5400000.0
# 3256                   Destroyer    Annapurna       1500000.0      4000000.0
# 3280  Bilal: A New Breed of Hero           VE        491000.0      1700000.0
#
#         year     id  production_budget  profitability
# 0     2010.0   47.0        200000000.0    867000000.0
# 3     2010.0   38.0        160000000.0    668300000.0
# 4     2010.0   27.0        165000000.0    587600000.0
# 5     2010.0   53.0         68000000.0    630500000.0
# 6     2010.0   15.0        170000000.0    453900000.0
# ...      ...    ...                ...            ...
# 3229  2018.0   15.0         15000000.0     -2300000.0
# 3238  2018.0   88.0         30000000.0    -20000000.0
# 3245  2018.0   81.0         20000000.0    -12100000.0
# 3256  2018.0    5.0          9000000.0     -3500000.0
# 3280  2018.0  100.0         30000000.0    -27809000.0
#
# [1077 rows x 8 columns]

# %%
highest_profitability = gross_and_prod.sort_values(by=["profitability"], ascending=False).head(100)
#Here  the profitability table with only 100 data points for the sake of graphing

# %%
highest_profitability.to_csv('profitability.csv')
#exported it to csv to use in other notebooks

# %%
highest_profitability_total = gross_and_prod.sort_values(by=["profitability"], ascending=False)
# Here is the entire profitability table

# %%
highest_profitability_total.to_csv('profitability_total.csv')
#exported it to csv to use in other notebooks

# %%
highest_profit = gross_and_prod.sort_values(by=["profitability"], ascending=False).head(100)

# %%
highest_profit2 = gross_and_prod.sort_values(by=["profitability"], ascending=False).head(200)
# I doubled the data points to better express the data in the table

# %%
 pd.set_option('float_format', '{:f}'.format)
# I added this line in to show entire numbers instead of numbers ^x. 
#It seemed to adjusted it the everything even before this line.

# %%
highest_profit.head(30)
# Out:
#                                           title   studio   domestic_gross  \
# 3089                              Black Panther       BV 700100000.000000
# 3090             Jurassic World: Fallen Kingdom     Uni. 417700000.000000
# 1131                                     Frozen       BV 400700000.000000
# 1883                                    Minions     Uni. 336000000.000000
# 1882                    Avengers: Age of Ultron       BV 459000000.000000
# 3091                              Incredibles 2       BV 608600000.000000
# 1132                                 Iron Man 3       BV 409000000.000000
# 3092                                    Aquaman       WB 335100000.000000
# 2770                            Despicable Me 3     Uni. 264600000.000000
# 332              Transformers: Dark of the Moon     P/DW 352400000.000000
# 732                                     Skyfall     Sony 304400000.000000
# 2331                 Captain America: Civil War       BV 408100000.000000
# 1133                            Despicable Me 2     Uni. 368100000.000000
# 1483            Transformers: Age of Extinction     Par. 245400000.000000
# 2334                                   Zootopia       BV 341300000.000000
# 2771             Jumanji: Welcome to the Jungle     Sony 404500000.000000
# 0                                   Toy Story 3       BV 415000000.000000
# 2332               Rogue One: A Star Wars Story       BV 532200000.000000
# 3093                          Bohemian Rhapsody      Fox 216400000.000000
# 2333                               Finding Dory       BV 486300000.000000
# 733                       The Dark Knight Rises       WB 448100000.000000
# 2336                    The Secret Life of Pets     Uni. 368400000.000000
# 735                  Ice Age: Continental Drift      Fox 161300000.000000
# 734           The Hobbit: An Unexpected Journey  WB (NL) 303000000.000000
# 1135            The Hunger Games: Catching Fire      LGF 424700000.000000
# 2339                                   Deadpool      Fox 363100000.000000
# 1134        The Hobbit: The Desolation of Smaug  WB (NL) 258399999.000000
# 1484  The Hobbit: The Battle of the Five Armies  WB (NL) 255100000.000000
# 2772                     Spider-Man: Homecoming     Sony 334200000.000000
# 1885                                 Inside Out       BV 356500000.000000
#
#         foreign_gross        year        id  production_budget  \
# 3089 646900000.000000 2018.000000 42.000000   200000000.000000
# 3090 891800000.000000 2018.000000 13.000000   170000000.000000
# 1131 875700000.000000 2013.000000 56.000000   150000000.000000
# 1883 823400000.000000 2015.000000 73.000000    74000000.000000
# 1882 946400000.000000 2015.000000  4.000000   330600000.000000
# 3091 634200000.000000 2018.000000 44.000000   200000000.000000
# 1132 805800000.000000 2013.000000 48.000000   200000000.000000
# 3092 812700000.000000 2018.000000 36.000000   160000000.000000
# 2770 770200000.000000 2017.000000 30.000000    75000000.000000
# 332  771400000.000000 2011.000000 64.000000   195000000.000000
# 732  804200000.000000 2012.000000 52.000000   200000000.000000
# 2331 745200000.000000 2016.000000 17.000000   250000000.000000
# 1133 602700000.000000 2013.000000 22.000000    76000000.000000
# 1483 858600000.000000 2014.000000 37.000000   210000000.000000
# 2334 682500000.000000 2016.000000 57.000000   150000000.000000
# 2771 557600000.000000 2017.000000 38.000000    90000000.000000
# 0    652000000.000000 2010.000000 47.000000   200000000.000000
# 2332 523900000.000000 2016.000000 45.000000   200000000.000000
# 3093 687200000.000000 2018.000000 84.000000    55000000.000000
# 2333 542300000.000000 2016.000000 46.000000   200000000.000000
# 733  636800000.000000 2012.000000 11.000000   275000000.000000
# 2336 507100000.000000 2016.000000 26.000000    75000000.000000
# 735  715900000.000000 2012.000000 14.000000    95000000.000000
# 734  718100000.000000 2012.000000 19.000000   250000000.000000
# 1135 440300000.000000 2013.000000 38.000000   130000000.000000
# 2339 420000000.000000 2016.000000 56.000000    58000000.000000
# 1134 700000000.000000 2013.000000 21.000000   250000000.000000
# 1484 700900000.000000 2014.000000 22.000000   250000000.000000
# 2772 546000000.000000 2017.000000 99.000000   175000000.000000
# 1885 501100000.000000 2015.000000 98.000000   175000000.000000
#
#          profitability
# 3089 1147000000.000000
# 3090 1139500000.000000
# 1131 1126400000.000000
# 1883 1085400000.000000
# 1882 1074800000.000000
# 3091 1042800000.000000
# 1132 1014800000.000000
# 3092  987800000.000000
# 2770  959800000.000000
# 332   928800000.000000
# 732   908600000.000000
# 2331  903300000.000000
# 1133  894800000.000000
# 1483  894000000.000000
# 2334  873800000.000000
# 2771  872100000.000000
# 0     867000000.000000
# 2332  856100000.000000
# 3093  848600000.000000
# 2333  828600000.000000
# 733   809900000.000000
# 2336  800500000.000000
# 735   782200000.000000
# 734   771100000.000000
# 1135  735000000.000000
# 2339  725100000.000000
# 1134  708399999.000000
# 1484  706000000.000000
# 2772  705200000.000000
# 1885  682600000.000000

# %%
import seaborn as sns

sns.set()


sns.scatterplot(x="production_budget", y="profitability",
           data=highest_profit);

# %%
plt.figure(figsize=(80,30))
ax = sns.jointplot(data=highest_profit2, x='production_budget', y='profitability', kind='reg', color='g')
plt.show()

# %%
fig = plt.figure(figsize=(15,10))
ax = sns.distplot(highest_profit["production_budget"].head(100))
;

ax.legend(labels=['production_budget','profitability'])
ax.set(xlabel='Production Budget', ylabel='Profitability')
ax.set_title('Production Budget VS Profitability')

plt.show()

# %% [markdown]
# ## Conclusion
#
# -Most studios spend below $200 million.
#
# -Movies that have a budget of one hundred million to two hundred million are most profitable.
