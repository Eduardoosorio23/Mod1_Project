# %%
import pandas as pd

# %%
# loading in db
movies = pd.read_csv('data/tmdb.movies.csv')
movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
movies.sort_values(by=["vote_average"], ascending=False).head(5)

# some vote_counts are only 1
# Out:
#        Unnamed: 0              genre_ids      id original_language  \
# 13258       13258                   [99]  403294                en
# 22787       22787               [27, 35]  444170                en
# 22592       22592                   [99]  488357                en
# 22607       22607                     []  437448                en
# 22610       22610  [9648, 37, 18, 10402]  463601                en
#
#                                           original_title  popularity  \
# 13258                                  9/11: Simulations       0.600
# 22787         Lasagna Cat - Telephone Sex Survey Results       0.722
# 22592                                  MOTO 9: The Movie       0.900
# 22607                                 The Letter Carrier       0.895
# 22610  Hope This Goes Over Well/Living in an Empty World       0.894
#
#       release_date                                              title  \
# 13258   2014-07-04                                  9/11: Simulations
# ...

# %%
movies.vote_count.mean()

#the mean is quite low
# Out:
# 194.22483689708488

# %%
movies.sort_values(by=['vote_count'], ascending=False).head(5)

# the highest vote_count is 22
# Out:
#        Unnamed: 0          genre_ids      id original_language original_title  \
# 4               4      [28, 878, 12]   27205                en      Inception
# 17383       17383       [28, 12, 35]  293660                en       Deadpool
# 5179         5179      [878, 28, 12]   24428                en   The Avengers
# 6               6  [28, 12, 14, 878]   19995                en         Avatar
# 11032       11032      [12, 18, 878]  157336                en   Interstellar
#
#        popularity release_date         title  vote_average  vote_count
# 4          27.920   2010-07-16     Inception           8.3       22186
# 17383      35.067   2016-02-12      Deadpool           7.6       20175
# 5179       50.289   2012-05-04  The Avengers           7.6       19673
# 6          26.526   2009-12-18        Avatar           7.4       18676
# 11032      28.440   2014-11-05  Interstellar           8.2       18597

# %%
# creating a list of all the vote_counts and sorting them
vote_count = movies.vote_count.tolist()
vote_count.sort()

# %%
# confirming highest vote_count
vote_count[-1]
# Out:
# 22186

# %%
import matplotlib.pyplot as plt

# %%
# the chart shows few vote counts are that high
plt.plot(vote_count)
plt.show()

# %%
# creating function to help see range of vote_counts
def divide_list(list, num1, num2):
    new_list = []
    for x in list:
        if (x > num1) & (x < num2):
            new_list.append(x)
    return new_list

# %%
# only 72 movies have vote counts between 10000 and 23000
len(divide_list(vote_count, 10000, 23000))
# Out:
# 72

# %%
#  creating a DF of movies with vote_counts 1000+
movies = movies[movies.vote_count > 999]

# %%
movies.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
movies.sort_values(by=["vote_count"], ascending = True).head()
# Out:
#        Unnamed: 0      genre_ids      id original_language original_title  \
# 14334       14334   [28, 35, 80]  268920                en    Hot Pursuit
# 17588       17588  [18, 14, 878]  339967                en       Colossal
# 20876       20876  [18, 14, 878]  339967                en       Colossal
# 20868       20868       [18, 53]  337674                fr           Elle
# 17584       17584       [18, 53]  337674                fr           Elle
#
#        popularity release_date        title  vote_average  vote_count
# 14334       9.607   2015-05-08  Hot Pursuit           5.6        1000
# 17588       9.790   2017-04-07     Colossal           6.1        1001
# 20876       9.790   2017-04-07     Colossal           6.1        1001
# 20868       9.870   2016-09-25         Elle           6.6        1003
# 17584       9.870   2016-09-25         Elle           6.6        1003

# %%
# 1108 movies have vote_counts 1000+
movies.shape
# Out:
# (1108, 10)

# %%
# deleting duplicates
movies = movies.drop_duplicates(subset='original_title').reset_index(drop=True)

# %%
# now 980 movies
movies.shape
# Out:
# (980, 10)

# %%
# It's somewhat arbitrary, but I'll work with movies that have more than 1000 votes. I don't want to use little seen movies
movies.sort_values(by=["vote_average"], ascending=False).head(10)
# Out:
#      Unnamed: 0              genre_ids      id original_language  \
# 658       17389        [10749, 16, 18]  372058                ja
# 927       23861        [18, 36, 10752]     424                en
# 547       14173        [16, 10751, 14]     129                ja
# 231        5201               [18, 80]     311                en
# 436       11031            [18, 10402]  244786                en
# 890       23812  [28, 12, 16, 878, 35]  324857                en
# 902       23827               [18, 35]  490132                en
# 862       20743        [18, 16, 10749]  378064                ja
# 4             4          [28, 878, 12]   27205                en
# 814       20660            [10749, 18]  398818                en
#
#                         original_title  popularity release_date  \
# 658                              君の名は。      28.238   2017-04-07
# 927                   Schindler's List      25.334   1993-12-15
# ...

# %%
# creating new DF for genre popularity

genre_pop = pd.DataFrame(columns=['popularity', 'title', 'vote_average', 'genre'])

# %%
genre_pop
# Out:
# Empty DataFrame
# Columns: [popularity, title, vote_average, genre]
# Index: []

# %%
# looking at the first movie 

movies.iloc[0:1]
# Out:
#    Unnamed: 0        genre_ids     id original_language  \
# 0           0  [12, 14, 10751]  12444                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788

# %%
# genre_ids are list of numbers, actually in a string. 
movies.iloc[0]['genre_ids']
# Out:
# '[12, 14, 10751]'

# %%
# function to isolate numbers

def split_ids(string):
    string = string[1:-1]
    numbers = list(string.split(','))
    new_list = []
    for i in numbers:
        new_list.append(int(i))
    return new_list

# %%
# testing function
split_ids(movies.iloc[0]['genre_ids'])
# Out:
# [12, 14, 10751]

# %%
# populating new DF using nested for loop
columns = ['title', 'genre', 'vote_average', 'popularity']
for i in range(len(movies)):
    ids = split_ids(movies.iloc[i]['genre_ids'])
    for j in range(len(ids)):
        popularity = movies.iloc[i]['popularity']
        title = movies.iloc[i]['title']
        avg = movies.iloc[i]['vote_average']
        genre = int(ids[j])
        values = [title, genre, avg, popularity]
        zipped = zip(columns, values)
        to_append = dict(zipped)
        genre_pop = genre_pop.append(to_append, True)
    
genre_pop
# Out:
#       popularity                                         title  vote_average  \
# 0         33.533  Harry Potter and the Deathly Hallows: Part 1           7.7
# 1         33.533  Harry Potter and the Deathly Hallows: Part 1           7.7
# 2         33.533  Harry Potter and the Deathly Hallows: Part 1           7.7
# 3         28.734                      How to Train Your Dragon           7.7
# 4         28.734                      How to Train Your Dragon           7.7
# ...          ...                                           ...           ...
# 2723      12.282                    Black Mirror: Bandersnatch           7.0
# 2724      11.542                                    The Ritual           6.0
# 2725       9.161                                    On My Skin           8.2
# 2726       8.693                              The Seventh Seal           8.2
# 2727       8.693                              The Seventh Seal           8.2
#
#       genre
# 0        12
# 1        14
# ...

# %%
# here are all the different genre codes
genre_pop.genre.unique()
# Out:
# array([12, 14, 10751, 16, 28, 878, 35, 53, 27, 80, 18, 10749, 9648, 36,
#        37, 10752, 10402, 10770], dtype=object)

# %%
# dropping all rows with NaN in genre
genre_pop.dropna(subset= ["genre"], inplace = True)

# %%
genre_pop.shape
# Out:
# (2728, 4)

# %%
genre_pop.head()
# Out:
#    popularity                                         title  vote_average  \
# 0      33.533  Harry Potter and the Deathly Hallows: Part 1           7.7
# 1      33.533  Harry Potter and the Deathly Hallows: Part 1           7.7
# 2      33.533  Harry Potter and the Deathly Hallows: Part 1           7.7
# 3      28.734                      How to Train Your Dragon           7.7
# 4      28.734                      How to Train Your Dragon           7.7
#
#    genre
# 0     12
# 1     14
# 2  10751
# 3     14
# 4     12

# %%
# new DF to rank movies with highest mean vote_average
top_votes = genre_pop.groupby("genre").mean().sort_values(by="vote_average", ascending=False).reset_index()
top_votes
# Out:
#     genre  popularity  vote_average
# 0   10402   16.418235      7.158824
# 1      36   15.133897      7.123077
# 2   10752   20.251667      7.076190
# 3      16   18.675648      6.976136
# 4      18   14.843052      6.959305
# 5   10770   13.515500      6.900000
# 6   10749   13.554824      6.823239
# 7   10751   18.098000      6.778814
# 8    9648   15.627510      6.669388
# 9      37   15.838714      6.635714
# 10     80   15.445532      6.634043
# 11     35   15.342366      6.580583
# 12    878   20.314792      6.579781
# 13     12   21.013972      6.551383
# 14     53   16.337363      6.501730
# 15     28   19.835667      6.472321
# 16     14   20.007601      6.471519
# 17     27   14.638077      6.180342

# %%
# new DF to rank movies with highest mean popularity
top_popularity = genre_pop.groupby("genre").mean().sort_values(by="popularity", ascending=False).reset_index()
top_popularity
# Out:
#     genre  popularity  vote_average
# 0      12   21.013972      6.551383
# 1     878   20.314792      6.579781
# 2   10752   20.251667      7.076190
# 3      14   20.007601      6.471519
# 4      28   19.835667      6.472321
# 5      16   18.675648      6.976136
# 6   10751   18.098000      6.778814
# 7   10402   16.418235      7.158824
# 8      53   16.337363      6.501730
# 9      37   15.838714      6.635714
# 10   9648   15.627510      6.669388
# 11     80   15.445532      6.634043
# 12     35   15.342366      6.580583
# 13     36   15.133897      7.123077
# 14     18   14.843052      6.959305
# 15     27   14.638077      6.180342
# 16  10749   13.554824      6.823239
# 17  10770   13.515500      6.900000

# %%
# getting names for each genre id from TMDB 
import json

def get_keys(path):
    with open(path) as f:
        return json.load(f)
keys = get_keys("/Users/halpe/.secret/tmdb_api.json")
api_key = keys['api_key']

# %%
import requests
url = "https://api.themoviedb.org/3/genre/movie/list?api_key={}&language=en-US".format(api_key)

# %%
response = requests.get(url)

# %%
# checking success of API call
response.text
# Out:
# '{"genres":[{"id":28,"name":"Action"},{"id":12,"name":"Adventure"},{"id":16,"name":"Animation"},{"id":35,"name":"Comedy"},{"id":80,"name":"Crime"},{"id":99,"name":"Documentary"},{"id":18,"name":"Drama"},{"id":10751,"name":"Family"},{"id":14,"name":"Fantasy"},{"id":36,"name":"History"},{"id":27,"name":"Horror"},{"id":10402,"name":"Music"},{"id":9648,"name":"Mystery"},{"id":10749,"name":"Romance"},{"id":878,"name":"Science Fiction"},{"id":10770,"name":"TV Movie"},{"id":53,"name":"Thriller"},{"id":10752,"name":"War"},{"id":37,"name":"Western"}]}'

# %%
response.json()["genres"]
# Out:
# [{'id': 28, 'name': 'Action'},
#  {'id': 12, 'name': 'Adventure'},
#  {'id': 16, 'name': 'Animation'},
#  {'id': 35, 'name': 'Comedy'},
#  {'id': 80, 'name': 'Crime'},
#  {'id': 99, 'name': 'Documentary'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 14, 'name': 'Fantasy'},
#  {'id': 36, 'name': 'History'},
#  {'id': 27, 'name': 'Horror'},
#  {'id': 10402, 'name': 'Music'},
#  {'id': 9648, 'name': 'Mystery'},
#  {'id': 10749, 'name': 'Romance'},
#  {'id': 878, 'name': 'Science Fiction'},
#  {'id': 10770, 'name': 'TV Movie'},
#  {'id': 53, 'name': 'Thriller'},
#  {'id': 10752, 'name': 'War'},
#  {'id': 37, 'name': 'Western'}]

# %%
# new DF for all the genre names
genre_codes = pd.DataFrame.from_dict(response.json()["genres"])

# %%
genre_codes
# Out:
#        id             name
# 0      28           Action
# 1      12        Adventure
# 2      16        Animation
# 3      35           Comedy
# 4      80            Crime
# 5      99      Documentary
# 6      18            Drama
# 7   10751           Family
# 8      14          Fantasy
# 9      36          History
# 10     27           Horror
# 11  10402            Music
# 12   9648          Mystery
# 13  10749          Romance
# 14    878  Science Fiction
# 15  10770         TV Movie
# 16     53         Thriller
# 17  10752              War
# 18     37          Western

# %%
genre_codes.dtypes
# Out:
# id       int64
# name    object
# dtype: object

# %%
# for some reason genre ids in my other DFs kept appearing as floats instead of integers. Converting them.
top_popularity = top_popularity.astype({'genre': 'int64'})

# %%
# for some reason genre ids in my other DFs kept appearing as floats instead of integers. Converting them.
top_votes = top_votes.astype({'genre': 'int64'})

# %%
# deleting unnecessary column
top_votes.drop(columns="popularity", inplace=True)

# %%
# merging DFs to be able read genres
top_votes = pd.merge(top_votes, genre_codes, left_on='genre', right_on='id').drop(columns=["id", "genre"])

# %%
top_votes
# Out:
#     vote_average             name
# 0       7.158824            Music
# 1       7.123077          History
# 2       7.076190              War
# 3       6.976136        Animation
# 4       6.959305            Drama
# 5       6.900000         TV Movie
# 6       6.823239          Romance
# 7       6.778814           Family
# 8       6.669388          Mystery
# 9       6.635714          Western
# 10      6.634043            Crime
# 11      6.580583           Comedy
# 12      6.579781  Science Fiction
# 13      6.551383        Adventure
# 14      6.501730         Thriller
# 15      6.472321           Action
# 16      6.471519          Fantasy
# 17      6.180342           Horror

# %%
# merging DFs to be able read genres
popularity = pd.merge(top_popularity, genre_codes, left_on='genre', right_on='id').drop(columns=["id", "genre", "vote_average"])

# %%
popularity
# Out:
#     popularity             name
# 0    21.013972        Adventure
# 1    20.314792  Science Fiction
# 2    20.251667              War
# 3    20.007601          Fantasy
# 4    19.835667           Action
# 5    18.675648        Animation
# 6    18.098000           Family
# 7    16.418235            Music
# 8    16.337363         Thriller
# 9    15.838714          Western
# 10   15.627510          Mystery
# 11   15.445532            Crime
# 12   15.342366           Comedy
# 13   15.133897          History
# 14   14.843052            Drama
# 15   14.638077           Horror
# 16   13.554824          Romance
# 17   13.515500         TV Movie

# %% [markdown]
# Popularity is an amorphous metric in TMDB See here: https://developers.themoviedb.org/3/getting-started/popularity
# But it's still useful for our purposes.
#
# Basically, the most popular genres are:
# 1. Adventure
# 2. Science Fiction
# 3. War
# 4. Fantasy
# 5. Action
#
# The movies with the highest vote averages are:
# 1. Music
# 2. History
# 3. War
# 4. Animation
# 5. Drama
