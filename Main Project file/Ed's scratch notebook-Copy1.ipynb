# %%
import pandas as pd
import os
from glob import glob

# %%
# glob finds all the files in a specified directory that match the condition
# we do this so we can open multiple files at once
csv_files = glob("./zippedData/*.csv.gz")
csv_files
# Out:
# ['./zippedData\\bom.movie_gross.csv.gz',
#  './zippedData\\imdb.name.basics.csv.gz',
#  './zippedData\\imdb.title.akas.csv.gz',
#  './zippedData\\imdb.title.basics.csv.gz',
#  './zippedData\\imdb.title.crew.csv.gz',
#  './zippedData\\imdb.title.principals.csv.gz',
#  './zippedData\\imdb.title.ratings.csv.gz',
#  './zippedData\\tmdb.movies.csv.gz',
#  './zippedData\\tn.movie_budgets.csv.gz']

# %%
# tsv files, because later tsv files need to be opened with sep='\t'
tsv_files = glob("./zippedData/*.tsv.gz")
tsv_files
# Out:
# ['./zippedData\\rt.movie_info.tsv.gz', './zippedData\\rt.reviews.tsv.gz']

# %%
data_dict = {}

for file in csv_files:
    data_dict[file] = pd.read_csv(file, encoding='latin_1')
    
for file in tsv_files:
    data_dict[file] = pd.read_csv(file, sep='\t', encoding='latin_1')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rating = pd.read_csv('zippedData/rt.movie_info.tsv.gz', sep='\t', encoding='latin_1') # rotten Tomatoes DB
rating
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper           NaN
# ...                                                ...           ...
# 1555                                               NaN  Aug 18, 2006
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                               NaN   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
# 1559                                        Luc Besson  Sep 27, 2001
#
#           dvd_date currency  box_office      runtime             studio
# 0     Sep 25, 2001      NaN         NaN  104 minutes                NaN
# 1      Jan 1, 2013        $     600,000  108 minutes  Entertainment One
# 2     Apr 18, 2000      NaN         NaN  116 minutes                NaN
# 3     Aug 27, 1997      NaN         NaN  128 minutes                NaN
# 4              NaN      NaN         NaN  200 minutes                NaN
# ...            ...      ...         ...          ...                ...
# 1555   Jan 2, 2007        $  33,886,034  106 minutes    New Line Cinema
# 1556  Apr 17, 2001      NaN         NaN   88 minutes  Paramount Vantage
# 1557  May 11, 2004      NaN         NaN  111 minutes                NaN
# 1558  Jan 29, 2002      NaN         NaN  101 minutes                NaN
# 1559  Feb 11, 2003      NaN         NaN   94 minutes  Columbia Pictures
#
# [1560 rows x 12 columns]

# %%
rating.drop('synopsis', axis=1, inplace=True)

# %%
rating.isna().sum()
# Out:
# id                 0
# rating             3
# genre              8
# director         199
# writer           449
# theater_date     359
# dvd_date         359
# currency        1220
# box_office      1220
# runtime           30
# studio          1066
# dtype: int64

# %%
reviews = pd.read_csv('zippedData/rt.reviews.tsv.gz', sep='\t', encoding='latin_1') #Rotten Tomatoes DB 
reviews
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
#                   critic  top_critic         publisher                date
# 0             PJ Nabarro           0   Patrick Nabarro   November 10, 2018
# 1         Annalee Newitz           0           io9.com        May 23, 2018
# 2           Sean Axmaker           0  Stream on Demand     January 4, 2018
# 3          Daniel Kasman           0              MUBI   November 16, 2017
# 4                    NaN           0      Cinema Scope    October 12, 2017
# ...                  ...         ...               ...                 ...
# 54427      Laura Sinagra           1     Village Voice  September 24, 2002
# 54428  Michael Szymanski           0        Zap2it.com  September 21, 2005
# 54429       Emanuel Levy           0   EmanuelLevy.Com       July 17, 2005
# 54430   Christopher Null           0    Filmcritic.com   September 7, 2003
# 54431    Nicolas Lacroix           0      Showbizz.net   November 12, 2002
#
# [54432 rows x 8 columns]

# %%
reviews.isna().sum() # Some Nulls, don't know how usefull this table will be
# Out:
# id                0
# review         5563
# rating        13517
# fresh             0
# critic         2722
# top_critic        0
# publisher       309
# date              0
# dtype: int64

# %%
title = pd.read_csv('zippedData/tmdb.movies.csv.gz') # The Movie DB
title
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 10 columns]

# %%
title.rename(columns={'original_title': 'title'}, inplace=True)
title
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                               title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 10 columns]

# %%
title.isna().sum() # No Nulls
# Out:
# Unnamed: 0           0
# genre_ids            0
# id                   0
# original_language    0
# title                0
# popularity           0
# release_date         0
# title                0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
title.set_index('title', inplace=True)
title
# Out:
#                                                     Unnamed: 0  \
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...           0
# (How to Train Your Dragon, How to Train Your Dr...           1
# (Iron Man 2, Iron Man 2)                                     2
# (Toy Story, Toy Story)                                       3
# (Inception, Inception)                                       4
# ...                                                        ...
# (Laboratory Conditions, Laboratory Conditions)           26512
# (_EXHIBIT_84xxx_, _EXHIBIT_84xxx_)                       26513
# (The Last One, The Last One)                             26514
# (Trailer Made, Trailer Made)                             26515
# (The Church, The Church)                                 26516
#
#                                                               genre_ids  \
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...      [12, 14, 10751]
# (How to Train Your Dragon, How to Train Your Dr...  [14, 12, 16, 10751]
# (Iron Man 2, Iron Man 2)                                  [12, 28, 878]
# (Toy Story, Toy Story)                                  [16, 35, 10751]
# (Inception, Inception)                                    [28, 878, 12]
# ...                                                                 ...
# (Laboratory Conditions, Laboratory Conditions)                 [27, 18]
# (_EXHIBIT_84xxx_, _EXHIBIT_84xxx_)                             [18, 53]
# (The Last One, The Last One)                               [14, 28, 12]
# (Trailer Made, Trailer Made)                            [10751, 12, 28]
# (The Church, The Church)                                       [53, 27]
#
#                                                         id original_language  \
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...   12444                en
# (How to Train Your Dragon, How to Train Your Dr...   10191                en
# (Iron Man 2, Iron Man 2)                             10138                en
# (Toy Story, Toy Story)                                 862                en
# (Inception, Inception)                               27205                en
# ...                                                    ...               ...
# (Laboratory Conditions, Laboratory Conditions)      488143                en
# (_EXHIBIT_84xxx_, _EXHIBIT_84xxx_)                  485975                en
# (The Last One, The Last One)                        381231                en
# (Trailer Made, Trailer Made)                        366854                en
# (The Church, The Church)                            309885                en
#
#                                                     popularity release_date  \
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...      33.533   2010-11-19
# (How to Train Your Dragon, How to Train Your Dr...      28.734   2010-03-26
# (Iron Man 2, Iron Man 2)                                28.515   2010-05-07
# (Toy Story, Toy Story)                                  28.005   1995-11-22
# (Inception, Inception)                                  27.920   2010-07-16
# ...                                                        ...          ...
# (Laboratory Conditions, Laboratory Conditions)           0.600   2018-10-13
# (_EXHIBIT_84xxx_, _EXHIBIT_84xxx_)                       0.600   2018-05-01
# (The Last One, The Last One)                             0.600   2018-10-01
# (Trailer Made, Trailer Made)                             0.600   2018-06-22
# (The Church, The Church)                                 0.600   2018-10-05
#
#                                                     vote_average  vote_count
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...           7.7       10788
# (How to Train Your Dragon, How to Train Your Dr...           7.7        7610
# (Iron Man 2, Iron Man 2)                                     6.8       12368
# (Toy Story, Toy Story)                                       7.9       10174
# (Inception, Inception)                                       8.3       22186
# ...                                                          ...         ...
# (Laboratory Conditions, Laboratory Conditions)               0.0           1
# (_EXHIBIT_84xxx_, _EXHIBIT_84xxx_)                           0.0           1
# (The Last One, The Last One)                                 0.0           1
# (Trailer Made, Trailer Made)                                 0.0           1
# (The Church, The Church)                                     0.0           1
#
# [26517 rows x 8 columns]

# %%
budgets = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
budgets
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
budgets.rename(columns={'movie': 'title'}, inplace=True)
budgets
# Out:
#       id  release_date                                        title  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
budgets.isna().sum() # No Nulls
# Out:
# id                   0
# release_date         0
# title                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
budgets.set_index('title', inplace=True)

# %%
studio = pd.read_csv('zippedData/bom.movie_gross.csv.gz')
studio
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %%
studio.isna().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
studio.set_index('title', inplace=True)
studio
# Out:
#                                                  studio  domestic_gross  \
# title
# Toy Story 3                                          BV     415000000.0
# Alice in Wonderland (2010)                           BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# Inception                                            WB     292600000.0
# Shrek Forever After                                P/DW     238700000.0
# ...                                                 ...             ...
# The Quake                                         Magn.          6200.0
# Edward II (2018 re-release)                          FM          4800.0
# El Pacto                                           Sony          2500.0
# The Swan                                     Synergetic          2400.0
# An Actor Prepares                                 Grav.          1700.0
#
#                                             foreign_gross  year
# title
# Toy Story 3                                     652000000  2010
# Alice in Wonderland (2010)                      691300000  2010
# Harry Potter and the Deathly Hallows Part 1     664300000  2010
# Inception                                       535700000  2010
# Shrek Forever After                             513900000  2010
# ...                                                   ...   ...
# The Quake                                             NaN  2018
# Edward II (2018 re-release)                           NaN  2018
# El Pacto                                              NaN  2018
# The Swan                                              NaN  2018
# An Actor Prepares                                     NaN  2018
#
# [3387 rows x 4 columns]

# %%
studio_and_budget = pd.merge(studio,
                   budgets[['id', 'production_budget']],
                   on='title', how='outer')
studio_and_budget.head()
# Out:
#                                             studio  domestic_gross  \
# title
# Toy Story 3                                     BV     415000000.0
# Alice in Wonderland (2010)                      BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# Inception                                       WB     292600000.0
# Shrek Forever After                           P/DW     238700000.0
#
#                                             foreign_gross    year    id  \
# title
# Toy Story 3                                     652000000  2010.0  47.0
# Alice in Wonderland (2010)                      691300000  2010.0   NaN
# Harry Potter and the Deathly Hallows Part 1     664300000  2010.0   NaN
# Inception                                       535700000  2010.0  38.0
# Shrek Forever After                             513900000  2010.0  27.0
#
#                                             production_budget
# title
# Toy Story 3                                      $200,000,000
# Alice in Wonderland (2010)                                NaN
# Harry Potter and the Deathly Hallows Part 1               NaN
# Inception                                        $160,000,000
# Shrek Forever After                              $165,000,000

# %%
studio_and_budget.to_csv('studio_and_budget.csv')

# %%
movie_data = pd.merge(title, 
                     studio_and_budget[['studio', 'domestic_gross', 'foreign_gross', 'year', 'id', 'production_budget']],
                     on='title', how='outer')
movie_data.head()
# Out:
#                                                     Unnamed: 0  \
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...         0.0
# (How to Train Your Dragon, How to Train Your Dr...         1.0
# (Iron Man 2, Iron Man 2)                                   2.0
# (Toy Story, Toy Story)                                     3.0
# (Toy Story, Toy Story)                                  2473.0
#
#                                                               genre_ids  \
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...      [12, 14, 10751]
# (How to Train Your Dragon, How to Train Your Dr...  [14, 12, 16, 10751]
# (Iron Man 2, Iron Man 2)                                  [12, 28, 878]
# (Toy Story, Toy Story)                                  [16, 35, 10751]
# (Toy Story, Toy Story)                                  [16, 35, 10751]
#
#                                                        id_x original_language  \
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...  12444.0                en
# (How to Train Your Dragon, How to Train Your Dr...  10191.0                en
# (Iron Man 2, Iron Man 2)                            10138.0                en
# (Toy Story, Toy Story)                                862.0                en
# (Toy Story, Toy Story)                                862.0                en
#
#                                                     popularity release_date  \
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...      33.533   2010-11-19
# (How to Train Your Dragon, How to Train Your Dr...      28.734   2010-03-26
# (Iron Man 2, Iron Man 2)                                28.515   2010-05-07
# (Toy Story, Toy Story)                                  28.005   1995-11-22
# (Toy Story, Toy Story)                                  28.005   1995-11-22
#
#                                                     vote_average  vote_count  \
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...           7.7     10788.0
# (How to Train Your Dragon, How to Train Your Dr...           7.7      7610.0
# (Iron Man 2, Iron Man 2)                                     6.8     12368.0
# (Toy Story, Toy Story)                                       7.9     10174.0
# (Toy Story, Toy Story)                                       7.9     10174.0
#
#                                                    studio  domestic_gross  \
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...    NaN             NaN
# (How to Train Your Dragon, How to Train Your Dr...    NaN             NaN
# (Iron Man 2, Iron Man 2)                              NaN             NaN
# (Toy Story, Toy Story)                                NaN             NaN
# (Toy Story, Toy Story)                                NaN             NaN
#
#                                                    foreign_gross  year  id_y  \
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...           NaN   NaN   NaN
# (How to Train Your Dragon, How to Train Your Dr...           NaN   NaN   NaN
# (Iron Man 2, Iron Man 2)                                     NaN   NaN   NaN
# (Toy Story, Toy Story)                                       NaN   NaN   NaN
# (Toy Story, Toy Story)                                       NaN   NaN   NaN
#
#                                                    production_budget
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...               NaN
# (How to Train Your Dragon, How to Train Your Dr...               NaN
# (Iron Man 2, Iron Man 2)                                         NaN
# (Toy Story, Toy Story)                                           NaN
# (Toy Story, Toy Story)                                           NaN

# %%
movie_data.drop('Unnamed: 0', axis=1, inplace=True)
movie_data
# Out:
#                                                               genre_ids  \
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...      [12, 14, 10751]
# (How to Train Your Dragon, How to Train Your Dr...  [14, 12, 16, 10751]
# (Iron Man 2, Iron Man 2)                                  [12, 28, 878]
# (Toy Story, Toy Story)                                  [16, 35, 10751]
# (Toy Story, Toy Story)                                  [16, 35, 10751]
# ...                                                                 ...
# Red 11                                                              NaN
# Following                                                           NaN
# Return to the Land of Wonders                                       NaN
# A Plague So Pleasant                                                NaN
# My Date With Drew                                                   NaN
#
#                                                        id_x original_language  \
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...  12444.0                en
# (How to Train Your Dragon, How to Train Your Dr...  10191.0                en
# (Iron Man 2, Iron Man 2)                            10138.0                en
# (Toy Story, Toy Story)                                862.0                en
# (Toy Story, Toy Story)                                862.0                en
# ...                                                     ...               ...
# Red 11                                                  NaN               NaN
# Following                                               NaN               NaN
# Return to the Land of Wonders                           NaN               NaN
# A Plague So Pleasant                                    NaN               NaN
# My Date With Drew                                       NaN               NaN
#
#                                                     popularity release_date  \
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...      33.533   2010-11-19
# (How to Train Your Dragon, How to Train Your Dr...      28.734   2010-03-26
# (Iron Man 2, Iron Man 2)                                28.515   2010-05-07
# (Toy Story, Toy Story)                                  28.005   1995-11-22
# (Toy Story, Toy Story)                                  28.005   1995-11-22
# ...                                                        ...          ...
# Red 11                                                     NaN          NaN
# Following                                                  NaN          NaN
# Return to the Land of Wonders                              NaN          NaN
# A Plague So Pleasant                                       NaN          NaN
# My Date With Drew                                          NaN          NaN
#
#                                                     vote_average  vote_count  \
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...           7.7     10788.0
# (How to Train Your Dragon, How to Train Your Dr...           7.7      7610.0
# (Iron Man 2, Iron Man 2)                                     6.8     12368.0
# (Toy Story, Toy Story)                                       7.9     10174.0
# (Toy Story, Toy Story)                                       7.9     10174.0
# ...                                                          ...         ...
# Red 11                                                       NaN         NaN
# Following                                                    NaN         NaN
# Return to the Land of Wonders                                NaN         NaN
# A Plague So Pleasant                                         NaN         NaN
# My Date With Drew                                            NaN         NaN
#
#                                                    studio  domestic_gross  \
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...    NaN             NaN
# (How to Train Your Dragon, How to Train Your Dr...    NaN             NaN
# (Iron Man 2, Iron Man 2)                              NaN             NaN
# (Toy Story, Toy Story)                                NaN             NaN
# (Toy Story, Toy Story)                                NaN             NaN
# ...                                                   ...             ...
# Red 11                                                NaN             NaN
# Following                                             NaN             NaN
# Return to the Land of Wonders                         NaN             NaN
# A Plague So Pleasant                                  NaN             NaN
# My Date With Drew                                     NaN             NaN
#
#                                                    foreign_gross  year  id_y  \
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...           NaN   NaN   NaN
# (How to Train Your Dragon, How to Train Your Dr...           NaN   NaN   NaN
# (Iron Man 2, Iron Man 2)                                     NaN   NaN   NaN
# (Toy Story, Toy Story)                                       NaN   NaN   NaN
# (Toy Story, Toy Story)                                       NaN   NaN   NaN
# ...                                                          ...   ...   ...
# Red 11                                                       NaN   NaN  78.0
# Following                                                    NaN   NaN  79.0
# Return to the Land of Wonders                                NaN   NaN  80.0
# A Plague So Pleasant                                         NaN   NaN  81.0
# My Date With Drew                                            NaN   NaN  82.0
#
#                                                    production_budget
# title
# (Harry Potter and the Deathly Hallows: Part 1, ...               NaN
# (How to Train Your Dragon, How to Train Your Dr...               NaN
# (Iron Man 2, Iron Man 2)                                         NaN
# (Toy Story, Toy Story)                                           NaN
# (Toy Story, Toy Story)                                           NaN
# ...                                                              ...
# Red 11                                                        $7,000
# Following                                                     $6,000
# Return to the Land of Wonders                                 $5,000
# A Plague So Pleasant                                          $1,400
# My Date With Drew                                             $1,100
#
# [34448 rows x 13 columns]

# %%
movie_data.isna().sum()
# Out:
# genre_ids             7931
# id_x                  7931
# original_language     7931
# popularity            7931
# release_date          7931
# vote_average          7931
# vote_count            7931
# studio               31057
# domestic_gross       31080
# foreign_gross        32404
# year                 31052
# id_y                 28666
# production_budget    28666
# dtype: int64
